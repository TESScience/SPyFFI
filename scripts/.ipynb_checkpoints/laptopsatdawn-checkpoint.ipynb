# %%
# import a tool that allows you to create different kinds of TESS observations
from SPyFFI import Observation

# %%
inputs = dict(

# these are necessary to specify
label='laptopsatdawn_nep',                # a label that will go into the output directory name
ra = 270.000, dec=66.56071,           # coordinates of the focal plane center
jitter=True,                          # should the spacecraft jitter?

# what outputs should be produced?
todo={120:100},                       # this will expose 100 images each at 120s cadences

# these options are optional, and can make for interesting movies
jitterscale=1.0,                      # by what factor should we magnify the jitter?
warpspaceandtime=1.0,                 # by what factor do we multiply the speed of light (to see DVA)
counterstep=1,                        # how many cadences (of the specified cadence) do we skip per frame? (to speed up time)

# these options relate to how stars are populated with light curves
fmax=0.00,                            # what fraction of eligible stars should get light curves
magmax=None,                          # stars fainter than this magnitude don't get light curves
extreme=False                        # if set to true, varaibility will be extreme (for movies)
)

# %%
# create a FFI of a particular patch of the sky, using catalog stars
obs = Observation.SkyFFI(**inputs)
# Out:
#        [skyffi] Creating a new Observation.
#        [skyffi] Setting up the camera for this Observation.
#        [camera] Turning on a new TESS camera object.
#        [camera] Setting cadence to 2 seconds = 1.0 reads.
#        [camera] Pointing the camera at (ra,dec) = 270.000000,66.560710
#           [psf] Initializing the TESS point spread function painter.
#           [psf] loaded PSF subpixel array definitions from
#                 ... /Users/zkbt/Cosmos/Data/TESS/FFIs/intermediates/original/pixelarrays.npy
#       [perfect] Creating an intrapixel sensitivity map called perfectpixels
#        [jitter] Populating the jitterball for 2 second cadence.
#         [ucac4] loading a catalog of stars from
#                 ... /Users/zkbt/Cosmos/Data/TESS/FFIs/intermediates/UCAC4_270.0_66.56071_17.70346373
#                 ... 75.npy
#         [ucac4] found 1420240 stars with 2.23799991608 < V < 17.5189990997

# %%
# add light curves to this observation's stellar catalog
obs.addLCs(**inputs)
# Out:
#         [ucac4] 1420240 stars are brighter than 18.258999059; populating 0.0% of them with light
#                 ... curves

# %%
# figure out the corners of the CCD
carto = obs.camera.cartographer
carto.setCCD(obs.camera.ccds[0])
carto.pithy = True

# the corner closest to the 
def report(x,y):
    c = carto.point(x,y,'ccdxy')
    print "{0} pixels".format(c.ccdxy)
    print "{0} pixels".format(c.focalxy)
    print "{0} degrees".format(c.celestial)


print "closest to camera center"
report(0,0)
print "farthest from camera center"
report(2047,2047)

print "the other two corners"
report(0,2047)
report(2047,0)
# Out:
# ccd1 (x, y) = (0,0) pixels
# focalplane (x, y) = (67.1666666667,67.1666666667) pixels
# celestial (ra, dec) = (268.994488427,66.9511964863) degrees
#
# ccd1 (x, y) = (0,2047) pixels
# focalplane (x, y) = (67.1666666667,2114.16666667) pixels
# celestial (ra, dec) = (268.026038279,78.7576281934) degrees
#
# ccd1 (x, y) = (2047,2047) pixels
# focalplane (x, y) = (2114.16666667,2114.16666667) pixels
# celestial (ra, dec) = (222.669197832,73.6638867596) degrees
#
# ccd1 (x, y) = (2047,0) pixels
# focalplane (x, y) = (2114.16666667,67.1666666667) pixels
# celestial (ra, dec) = (241.081462018,64.0794447339) degrees

# %%
print cartographer.coordinate

# %%
print cartographer.coordinate

# %%
# create the observation, generating all exposures
obs.create(**inputs)
# Out:
#        [camera] Setting cadence to 120 seconds = 60.0 reads.
#        [jitter] Populating the jitterball for 120 second cadence.
#        [jitter] Jittering the camera to -0.0703140045491,-0.0893734051301,-0.338751487966 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] setting up this CCD's starmap
#           [ccd] the camera already had a catalog of 1420240 elements defined; using it!
#           [ccd] taking an intial snapshot at 2457827.0 = 2017.20054757
#         [ucac4] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#       [trimmed] projecting catalog 17.201 years relative to 2000
#       [trimmed] save projected star catalog /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d3
#                 ... 3m39s_laptopsatdawn_SkyFFI/120s/ccd1/catalog_18h00m00s+66d33m39s_ccd1.txt
#           [ccd] taking a snapshot at 2457827.0 = 2017.20054757
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 127865 stars to image
#           [psf] loaded binned PSFs from /Users/zkbt/Cosmos/Data/TESS/FFIs/intermediates/original/pix
#                 ... elizedlibrary_0120s_10radii_21offsets_10degrees_10000K_perfectpixels.npy
#           [ccd] Adding backgrounds.
#           [ccd] trying to load image from /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/backgrounds.fits
#           [ccd]        ...failed.
#           [ccd]    including smooth model for zodiacal light.
#           [ccd]    including smooth model for unresolved stars in the Galaxy.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/backgrounds.fits with type float32
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/noiseless_18h00m00s+66d33m39s_ccd1_000000.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/photonnoise.fits with type float32
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/cosmics_18h00m00s+66d33m39s_ccd1_000000.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/readoutsmear.fits with type float32
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.97205673869;
#                 ... and the flux change over entire image is 7.62939453125e-06 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.10420123235;
#                 ... and the flux change over entire image is 0.0 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is 0.0 electrons
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/saturation_150000p0K.fits with type float32
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/simulated_18h00m00s+66d33m39s_ccd1_000000.fit
#                 ... s with type int32
#           [ccd] created image #0000000 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0703140045491,-0.0893734051301,-0.338751487966 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] setting up this CCD's starmap
#           [ccd] the camera already had a catalog of 1420240 elements defined; using it!
#           [ccd] taking an intial snapshot at 2457827.0 = 2017.20054757
#         [ucac4] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#       [trimmed] projecting catalog 17.201 years relative to 2000
#       [trimmed] save projected star catalog /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d3
#                 ... 3m39s_laptopsatdawn_SkyFFI/120s/ccd2/catalog_18h00m00s+66d33m39s_ccd2.txt
#           [ccd] taking a snapshot at 2457827.0 = 2017.20054757
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 218883 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] trying to load image from /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/backgrounds.fits
#           [ccd]        ...failed.
#           [ccd]    including smooth model for zodiacal light.
#           [ccd]    including smooth model for unresolved stars in the Galaxy.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/backgrounds.fits with type float32
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/noiseless_18h00m00s+66d33m39s_ccd2_000000.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/photonnoise.fits with type float32
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/cosmics_18h00m00s+66d33m39s_ccd2_000000.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/readoutsmear.fits with type float32
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.50856735653;
#                 ... and the flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.03111454915;
#                 ... and the flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/saturation_150000p0K.fits with type float32
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/simulated_18h00m00s+66d33m39s_ccd2_000000.fit
#                 ... s with type int32
#           [ccd] created image #0000000 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0703140045491,-0.0893734051301,-0.338751487966 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] setting up this CCD's starmap
#           [ccd] the camera already had a catalog of 1420240 elements defined; using it!
#           [ccd] taking an intial snapshot at 2457827.0 = 2017.20054757
#         [ucac4] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#       [trimmed] projecting catalog 17.201 years relative to 2000
#       [trimmed] save projected star catalog /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d3
#                 ... 3m39s_laptopsatdawn_SkyFFI/120s/ccd3/catalog_18h00m00s+66d33m39s_ccd3.txt
#           [ccd] taking a snapshot at 2457827.0 = 2017.20054757
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 265972 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] trying to load image from /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/backgrounds.fits
#           [ccd]        ...failed.
#           [ccd]    including smooth model for zodiacal light.
#           [ccd]    including smooth model for unresolved stars in the Galaxy.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/backgrounds.fits with type float32
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/noiseless_18h00m00s+66d33m39s_ccd3_000000.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/photonnoise.fits with type float32
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/cosmics_18h00m00s+66d33m39s_ccd3_000000.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/readoutsmear.fits with type float32
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.44825122354;
#                 ... and the flux change over entire image is -3.0517578125e-05 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.03099457856;
#                 ... and the flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/saturation_150000p0K.fits with type float32
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/simulated_18h00m00s+66d33m39s_ccd3_000000.fit
#                 ... s with type int32
#           [ccd] created image #0000000 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0703140045491,-0.0893734051301,-0.338751487966 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] setting up this CCD's starmap
#           [ccd] the camera already had a catalog of 1420240 elements defined; using it!
#           [ccd] taking an intial snapshot at 2457827.0 = 2017.20054757
#         [ucac4] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#       [trimmed] projecting catalog 17.201 years relative to 2000
#       [trimmed] save projected star catalog /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d3
#                 ... 3m39s_laptopsatdawn_SkyFFI/120s/ccd4/catalog_18h00m00s+66d33m39s_ccd4.txt
#           [ccd] taking a snapshot at 2457827.0 = 2017.20054757
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 138527 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] trying to load image from /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/backgrounds.fits
#           [ccd]        ...failed.
#           [ccd]    including smooth model for zodiacal light.
#           [ccd]    including smooth model for unresolved stars in the Galaxy.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/backgrounds.fits with type float32
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/noiseless_18h00m00s+66d33m39s_ccd4_000000.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/photonnoise.fits with type float32
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/cosmics_18h00m00s+66d33m39s_ccd4_000000.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/readoutsmear.fits with type float32
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.87836610766;
#                 ... and the flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.20092964285;
#                 ... and the flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/saturation_150000p0K.fits with type float32
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/simulated_18h00m00s+66d33m39s_ccd4_000000.fit
#                 ... s with type int32
#           [ccd] created image #0000000 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0791777084578,0.0200916480085,-0.137103807067 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] taking a snapshot at 2457827.00139 = 2017.20055137
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 127865 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/noiseless_18h00m00s+66d33m39s_ccd1_000001.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/cosmics_18h00m00s+66d33m39s_ccd1_000001.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.97043526712;
#                 ... and the flux change over entire image is 2.28881835938e-05 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.09750349991;
#                 ... and the flux change over entire image is 3.0517578125e-05 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is 3.0517578125e-05 electrons
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/simulated_18h00m00s+66d33m39s_ccd1_000001.fit
#                 ... s with type int32
#           [ccd] created image #0000001 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0791777084578,0.0200916480085,-0.137103807067 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] taking a snapshot at 2457827.00139 = 2017.20055137
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 218883 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/noiseless_18h00m00s+66d33m39s_ccd2_000001.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/cosmics_18h00m00s+66d33m39s_ccd2_000001.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.50620139276;
#                 ... and the flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.03473506751;
#                 ... and the flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is -1.52587890625e-05 electrons
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd2/simulated_18h00m00s+66d33m39s_ccd2_000001.fit
#                 ... s with type int32
#           [ccd] created image #0000001 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0791777084578,0.0200916480085,-0.137103807067 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] taking a snapshot at 2457827.00139 = 2017.20055137
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 265972 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/noiseless_18h00m00s+66d33m39s_ccd3_000001.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/cosmics_18h00m00s+66d33m39s_ccd3_000001.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.43639194685;
#                 ... and the flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.03594602694;
#                 ... and the flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd3/simulated_18h00m00s+66d33m39s_ccd3_000001.fit
#                 ... s with type int32
#           [ccd] created image #0000001 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to -0.0791777084578,0.0200916480085,-0.137103807067 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] taking a snapshot at 2457827.00139 = 2017.20055137
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 138527 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/noiseless_18h00m00s+66d33m39s_ccd4_000001.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/cosmics_18h00m00s+66d33m39s_ccd4_000001.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.87647787066;
#                 ... and the flux change over entire image is 7.62939453125e-06 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.20219814896;
#                 ... and the flux change over entire image is 7.62939453125e-06 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is 1.52587890625e-05 electrons
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd4/simulated_18h00m00s+66d33m39s_ccd4_000001.fit
#                 ... s with type int32
#           [ccd] created image #0000001 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to 0.0617480930415,-0.0418360106492,0.467636838599 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] taking a snapshot at 2457827.00278 = 2017.20055518
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 127865 stars to image
#           [ccd] Adding backgrounds.
#           [ccd] saving noiseless TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/noiseless_18h00m00s+66d33m39s_ccd1_000002.fit
#                 ... s with type int32
#           [ccd] Adding photon noise [sqrt(photons from stars and various backgrounds)].
#           [ccd] Adding cosmic rays
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/cosmics_18h00m00s+66d33m39s_ccd1_000002.fits
#                 ... with type float32
#           [ccd] Adding readout smear.
#           [ccd]     assuming 0.005 second readout times on 2.0 second exposures.
#           [ccd] Bleeding saturated pixels.
#           [ccd] on pass #1 through saturation filter: the max saturation fraction is 1.95807986562;
#                 ... and the flux change over entire image is 0.0 electrons
#           [ccd] on pass #2 through saturation filter: the max saturation fraction is 1.10239895473;
#                 ... and the flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] on pass #3 through saturation filter: the max saturation fraction is 1.0; and the
#                 ... flux change over entire image is -7.62939453125e-06 electrons
#           [ccd] Adding read noise.
#           [ccd]     = quadrature sum of [120 seconds]/[2.0 seconds] = 60.0 reads with 10.0 e- each.
#           [ccd] saving final TESS image
#           [ccd] saving 2048x2048 image to /Users/zkbt/Cosmos/Data/TESS/FFIs/outputs/18h00m00s+66d33m
#                 ... 39s_laptopsatdawn_SkyFFI/120s/ccd1/simulated_18h00m00s+66d33m39s_ccd1_000002.fit
#                 ... s with type int32
#           [ccd] created image #0000002 of 18h00m00s+66d33m39s with 120s cadence
#        [jitter] Jittering the camera to 0.0617480930415,-0.0418360106492,0.467636838599 away from
#                 ... nominal pointing.
#           [ccd] Adding stars.
#           [ccd] projecting the starmap onto CCD
#           [ccd] taking a snapshot at 2457827.00278 = 2017.20055518
#       [trimmed] projecting catalog 17.201 years relative to 2000
#           [ccd]   done!
#           [ccd] adding 218883 stars to image
